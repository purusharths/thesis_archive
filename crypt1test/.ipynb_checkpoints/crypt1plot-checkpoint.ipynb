# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
m1 = np.load("crypt1_test4_mat1.npy")
m2 = np.load("crypt1_test4_mat2.npy")
m3 = np.load("crypt1_test4_mat3.npy")
overall = np.load("crypt1_test4_overall.npy")

# %%
overall0 = np.load("crypt1_test0_overall.npy")
overall1 = np.load("crypt1_test1_overall.npy")
overall2 = np.load("crypt1_test2_overall.npy")
overall3 = np.load("crypt1_test3_overall.npy")
overall4 = np.load("crypt1_test4_overall.npy")
overall5 = np.load("crypt1_test5_overall.npy")

# %%
plt.plot(overall0, '--')
plt.plot(overall1, '--')
plt.plot(overall2, '--')
plt.plot(overall3, '--')
plt.plot(overall4, '--')
plt.plot(overall5, '--')

# %%
d ={'col0': overall0,
     'col1': overall1,
     'col2': overall2,
     'col3': overall3,
     'col4': overall4,
     'col5': overall5}

# %%
df = pd.DataFrame(data=d)

# %%
median = df.median()

# Plot with median line and shaded area for uncertainty
plt.figure(figsize=(8, 6))
for col in df.columns:
    sns.lineplot(data=df[col], errorbar='sd')  # 'sd' for shading based on standard deviation

# Plot median line
#plt.plot(median, color='black', label='Median', linewidth=2)

plt.legend()
plt.show()
# Out:
# /home/purusharth/.envs/base/lib64/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/purusharth/.envs/base/lib64/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/purusharth/.envs/base/lib64/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# row_medians = df.median(axis=1)
row_stats = df.agg(['min', 'max', 'median'], axis=1)
# plt.plot(row_stats['median'])
# plt.plot(row_stats['min'])
# plt.plot(row_stats['max'])

medians = np.median(df, axis=1)
mins = np.min(df, axis=1)
maxs = np.max(df, axis=1)

plt.figure(figsize=(8, 6))
sns.lineplot(x=range(len(medians)), y=medians, color='indigo')
plt.fill_between(range(len(mins)), mins, maxs, color='indigo', alpha=0.1)
plt.xlabel('Rows')
plt.ylabel('Values')
plt.legend()
plt.show()
# Out:
# /home/purusharth/.envs/base/lib64/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/purusharth/.envs/base/lib64/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/purusharth/.envs/base/lib64/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns


def plot_lines(file_list, x_label_ = "", y_label_ ="", title="", savefig_name="default.pdf"):
    for array in file_list:
        plt.plot(array, '--')
    plt.xlabel(x_label_)
    plt.ylabel(y_label_)
    plt.title(title)
    plt.savefig(savefig_name)

# %%
# row_stats_mat1 = df.agg(['min', 'max', 'median'], axis=1)
# row_medians = df.median(axis=1)

# plt.plot(row_stats['median'])
# plt.plot(row_stats['min'])
# plt.plot(row_stats['max'])
N = 6
CryptNum = 1
name = [f"crypt{CryptNum}_test_overall", f"crypt{CryptNum}_mat1", f"crypt{CryptNum}_mat2", f"crypt{CryptNum}_mat3"]
loadtype = ["overall", "mat1", "mat2", "mat3"]
OVERALL = [np.load(f"overall/{name}{i}_{loadtype[0]}.npy") for i in range(N)]
OVERALL = [np.load(f"mat1/{name}{i}_{loadtype[1]}.npy") for i in range(N)]
OVERALL = [np.load(f"mat2/{name}{i}_{loadtype[2]}.npy") for i in range(N)]
OVERALL = [np.load(f"mat3/{name}{i}_{loadtype[3]}.npy") for i in range(N)]

plot_lines(OVERALL, savefig_name = name)


d = {f'col{i}': array for i, array in enumerate(OVERALL)}
df = pd.DataFrame(data=d)




mat1_medians = np.median(df, axis=1)
mat1_mins = np.min(df, axis=1)
mat2_maxs = np.max(df, axis=1)

plt.figure(figsize=(8, 6))
sns.lineplot(x=range(len(medians)), y=medians, color='indigo')
plt.fill_between(range(len(mins)), mins, maxs, color='indigo', alpha=0.1)
# plt.xlabel('Rows')
# plt.ylabel('Values')
plt.legend()
plt.show()
# Out:
# /home/purusharth/.envs/base/lib64/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/purusharth/.envs/base/lib64/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/purusharth/.envs/base/lib64/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
